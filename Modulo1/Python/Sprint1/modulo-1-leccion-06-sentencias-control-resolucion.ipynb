# %% [markdown]
# # Resolución ejercicios Sentencias booleanas

# %% [markdown]
# ---
#
#
# ## Ejercicios: comparaciones y `if`
#
# - Crea las siguientes variables:
#
#   1. `var1` sea un número con el valor `8`.
#   2. `var2` sea un número con el valor `2`.
#   3. `var3` sea un número con el valor `8`.
#
# - Evalua los siguientes casos, usando `print()`:
#
#   4. ¿Es `var1` mayor que `var2`?
#   5. ¿Es `var1` menor o igual a `var3`?
#   6. ¿Es `var1` menor o igual a `var2`?
#   7. ¿Es `var2` distinto que `var3`?
#   8. ¿Es `var2` igual a `var3`?
#   9. ¿Es `var1` mayor que `var3`?
#
# - Añade una consecuencia a la condición `True`
#
#   10. Comprueba si `var1` es mayor que 6, y si es así imprime `¡Es enorme!`.
#   11. Comprueba si `var2` es mayor que 6, y si es así imprime `¡Es enorme también!`.
#   12. Comprueba si `var3` es mayor que 6, y si es así imprime `¡Es enorme!` seguido por `¡Pero de verdad!` en otra línea si se cumple la condición (deberéis tener dos *print*).
#
# - Bonus
#
#   13. Comprueba si `var1` es igual que `var3`, y si es así imprime `Son iguales.`.
#   14. Comprueba si `var1` es igual que `var2`, y si es así imprime `Son iguales.`
#   15. Comprueba si `var1` es mayor o igual que `var2`, y si es así calcula la diferencia entre `var1` y `var2`, guardala en la variable `dif`, e imprime `'La diferencia es',dif`.
#
# ---

# %%
var1 = 8
var2 = 2
var3 = 8

print(var1 > var2)
print(var1 <= var3)
print(var1 <= var2)
print(var2 != var3)
print(var2 == var3)
print(var1 > var3)

if var1 > 6: 
  print('¡Es enorme!')

if var2 > 6: 
  print('¡Es enorme también!')

if var3 > 6: 
  print('¡Es enorme!')
  print('¡Pero de verdad!')

# Bonus
if var1 == var3:
  print('Son iguales.')
print('Consideramos var1 y var3')

if var1 == var2:
  print('Son iguales.')

if var1 >= var2:
  dif = var1 - var2
  print('La diferencia es',dif)
# Out:
# True
# True
# False
# True
# False
# False
# ¡Es enorme!
# ¡Es enorme!
# ¡Pero de verdad!
# Son iguales.
# Consideramos var1 y var3
# Consideramos var1 y var2
# La diferencia es 6
# Consideramos var1 y var2

# %% [markdown]
# ---
#
#
# ## Ejercicios: `if` - `else`
#
# - Crea las siguientes variables:
#
#   16. `var1` sea un número con el valor `8`.
#   17. `var2` sea un número con el valor `2`.
#   18. `var3` sea un número con el valor `8`.
#
# - Evalua los siguientes casos, usando `if`, `else`, y `print()`:
#
#   19. Comprueba si `var1` es mayor que 6, y si es así imprime `¡Es enorme!`. Si no es así imprime `Es chiquitín.`.
#   20. Comprueba si `var2` es mayor que 6, y si es así imprime `¡Es enorme también!`. Si no es así imprime `Es chiquitín también.`.
#   21. Comprueba si `var1` es igual a `var3`, y si es así imprime `Son iguales.` Si no es así imprime `Son distintos.` Sigalo en otra línea con `Consideramos las variables var1 y var3.` (deberéis tener dos *prints*)
#   22. Comprueba si `var2` es igual a `var3`, y si es así imprime `Son iguales.` Si no es así imprime `Son distintos.` Sigalo en otra línea con `Consideramos las variables var2 y var3.` (deberéis tener dos *prints*)
# - Bonus
#
#   23. Comprueba si `var2` es menor o igual a `var3`, y si es así calcula la diferencia entre `var3` y `var2`, guardala en la variable `dif`, e imprime `var2 no es mayor que var3.`. Sigalo en otra línea con `La diferencia es ` seguido por el valor de la variable `dif`, pero sólo si se ha cumplido la condición. Si no se cumple, imprime `var2 es mayor que var3.`. En todo caso queremos que se imprima `Este línea siempre se imprime.`.
#
#
# ---

# %%
var1 = 8
var2 = 2
var3 = 8

# ejercicio 19
if var1 > 6: 
  print('¡Es enorme!')
else:
  print('Es chiquitín.')

# ejercicio 20
if var2 > 6: 
  print('¡Es enorme también!')
else:
  print('Es chiquitín también.')

# ejericio 21
if var1 == var3:
  print('Son iguales.')
else:
  print('Son distintos.')
print('Consideramos var1 y var3.')

# ejercicio 22
if var2 == var3:
  print('Son iguales.')
else:
  print('Son distintos.')
print('Consideramos var2 y var3.')

# Bonus
if var2 <= var3:
  dif = var3 - var2
  print('var2 no es más grande que var3.')
  print('La diferencia es', dif)
else:
  print('var2 no es más grande que var3.')
print('Este línea siempre se imprime.')
# Out:
# ¡Es enorme!
# Es chiquitín también.
# Son iguales.
# Consideramos var1 y var3.
# Son distintos.
# Consideramos var2 y var3.
# var2 no es más grande que var3.
# La diferencia es 6
# Este línea siempre se imprime.

# %% [markdown]
# ---
#
#
# ## Ejercicios: `if` - `elif` - `else`
#
# - Crea las siguientes variables:
#
#   24. `var1` sea un número con el valor `8`.
#   25. `var2` sea un número con el valor `2`.
#   26. `var3` sea un número con el valor `8`.
#
# - Evalua los siguientes casos, usando `if`, `elif`, `else`, y `print()`:
#
#   27. Comprueba si `var1` es menor que 3, si no es así, mira si es mayor que 15. En el primer caso, imprime `Qué pequeño es.`, en el segundo caso imprime `¡Que grande!`. En los demás casos imprime `Así me gusta.`.
#   28. Comprueba si `var1` es mayor que 3 e imprime `¡Qué grande es!`, si no es así, mira si es menor o igual a `var3` e imprime `¡Qué pequeño es!`.Además chequead si `var1` es mayor que `var3`
#
# - Bonus
#
#   29. Cambia el código que hiciste en la 28. pero en este caso querremos saber si:
#     - `var1`es menor que 3, en este caso printead "Qué pequeño es"
#     - `var1` > `var3`, en este caso printeas "Qué grande"
#     - En caso de que no se cumplan ninguna de las condiciones, printead "Qué pequeño es".
#
# ---

# %%
var1 = 8
var2 = 2
var3 = 8

# ejercicio 27
if var1 < 3:
  print('Qué pequeño es.')
elif var1 > 15:
  print('¡Tan grande!')
else:
  print('Así me gusta.')



# ejercicio 28
if var1 > 3:
  print('Qué grande!')    # valores más grande que 3, (3,inf]
elif var1 <= var3:
  print('Qué pequeño es.') # valores más pequeño que 3, [-inf,3] si var3 > 3, [-inf, var3] si var3 < 3
else:
  print('Nunca se llegaría aquí, porque var3 > 3.') # si var3 fuera < 3 aquí entrarían los valores entremedio


# ejercicio 29
if var1 < 3:
  print('Qué pequeño es.') # valores más pequeño que 3, la frase ya no apunta a valores entre 3 y var3
elif var1 > var3:
  print('Qué grande!')    # valores más grandes que var3, la frase ya no apunta a valores entre 3 y var3
else:
  print('Qué pequeño es.') # valores entremedio

# %% [markdown]
# ---
#
#
# ## Ejercicios: Condiciones múltiples
#
# - Cread las siguientes variables:
#
#   30. `dia_recoger_basura` sea un número con el valor `12`.
#
#   31. `dia_hoy` sea un número con el valor `6`.
#
#   32. `cubo_lleno` sea un booleano con el valor `True`.
#
#   33. `aviso` sea un *str* con el valor `'Tienes que vaciar el cubo de basura.'`.
#
# - Evalua las siguientes condiciones:
#
#   34. En el caso que `dia_hoy` sea igual a `(dia_recoger_basura - 1)` quiero ser avisado si `cubo_lleno` es `True`. Usa un solo `if`. Imprime `aviso`. En los demás casos no quiero que me avise.
#
#   35. En el caso que queden 5 *o menos* días hasta que vengan a recoger la basura, y el cubo no este vacío, avísame con el aviso predeterminado.
#
# - Bonus
#
#   36. El día en que vengan a recoger la basura, vienen muy temprano, y entonces no es posible ir a vaciar el cubo el mismo día. El día después de que hayan venido tampoco me interesa. Cambia el código de la 35. para que sea un rango. Ojo que la diferencia entre las fechas puede ser negativa. Amplia el aviso predeterminado con `Quedan X días hasta la recogida.` con la cantidad de días en el sitio marcado con X.
#
# ---

# %%
dia_recoger_basura = 12
dia_hoy = 11
cubo_lleno = True
aviso = 'Tienes que vaciar el cubo de basura.'

# ejericicio 34
if dia_hoy == dia_recoger_basura - 1 and cubo_lleno:
  print(aviso + ' (1)')

# ejercicio 35
if dia_recoger_basura - dia_hoy <= 5 and cubo_lleno:
  print(aviso + ' (2)')

# Bonus ejercicio 36
if 0 < (dia_recoger_basura - dia_hoy) <= 5 and cubo_lleno: # sin parenthesis no funciona bien en todos los casos
  print(aviso + ' (3)')
  print('Quedan',dia_recoger_basura - dia_hoy,'días hasta la recogida.')
# Out:
# Tienes que vaciar el cubo de basura. (1)
# Tienes que vaciar el cubo de basura. (2)
# Tienes que vaciar el cubo de basura. (3)
# Quedan 1 días hasta la recogida.

# %% [markdown]
# ## Ejercicio Sentencias booleanas
# 37. En la imagen de abajo ves 6 burbujas: dos grises, tres turquesas, y una turquesa oscura, con las siguientes condiciones:
#
# - Si el número de `peras` pertenece a la burbuja `E` nuestro código debe devolver la frase `El rojo es mi color favorito.`.
#
# - Si el numero de `peras` pertenece a `A` pero **no** a `F` imprime `El verde es mi color favorito.`.
#
# - Si la cantidad de `peras` pertenece a la burbuja `B` o `F` imprime `El amarillo es mi color favorito.`.

# %% [markdown]
# ![subsets2.png](data:image/png;base64,...)

# %%
peras = 10


if peras < 50:
  print("mi color favorito es el verde")
elif peras == 50 or peras <= 0:
  print("mi color favorito es el amarillo")
elif peras == 50 or peras > 50:
  print("mi color favorito es el rojo")
# Out:
# mi color favorito es el verde

# %% [markdown]
# ---
#
# ## Ejercicios `while`
#
# - Bucles `while`
#
#     38. Inicia `ahorros` con un valor de `5`. Mientras los ahorros sean igual a o menor que `20` imprime la cantidad de ahorros, y añádele `5` más.
#
#     39. Si cambias el orden de imprimir y añadir `5`, ¿qué resultado te esperas? Compruébalo.
#
# ---

# %%
# 32.
print('--- 32. ---')
ahorros = 5
while ahorros <= 20:
    print(ahorros)
    ahorros += 5


# 33.
print('--- 33. ---')
ahorros = 5
while ahorros <= 20:
    ahorros += 5
    print(ahorros)

# 34.
print('--- 34. ---')
ahorros = 5
while ahorros <= 20:
    print(ahorros)
    ahorros += 5
    if ahorros >= 12:
        break
# Out:
# --- 32. ---
# 5
# 10
# 15
# 20
# --- 33. ---
# 10
# 15
# 20
# 25
# --- 34. ---
# 5
# 10

# %% [markdown]
# ---
#
# ## Ejercicios `try:` `except:` `else:` `finally:`
#
# - `try:`, `except:`
#
#     35. Defina `doce = '12'` y `seis = 6`. Intenta sumirlos. En el caso de que te salga un error imprime `'¡Un error!'`
#     36. En el ejercicio 35. haz que imprime qué error ha tenido.
#     37. Cambia tu solución de 36. para que devuelva el *tipo*  de error que ha sido.
#     38. Especifíca un except con el tipo del ejercicio 37. *Dentro* de ese except, cambia `doce + seis` por `int(doce) + int(seis)` en un `print()` y mira qué pasa.
#
# - `else:`, `finally:`
#
#     39. En el caso de que 35. te salga sin errores, querrás imprimir `'Todo bien por aquí.'` Cambia la variable `doce` para llegar a imprimirlo.
#     40. Amplia 39. con 'Se acabó el try.' que te sale siempre al acabar el try.
#
# ---

# %%
doce = '12'
seis = 6

# 35.
try: 
    doce + seis
except:
    print('35. ¡Un error!') 

# 36.
try: 
    doce + seis
except Exception as e:
    print('36. ¡Un error!', e) 

# 37.
try: 
    doce + seis
except Exception as e:
    print('37.', type(e)) 

# 38.
try: 
    doce + seis
except TypeError:
    print('38.', int(doce)+int(seis) )

# 39.
doce = 12
try: 
    doce + seis
except:
    print('39. ¡Un error!') 
else:
    print('39. Todo bien por aquí.')

# 40.
try: 
    doce + seis
except:
    print('40. ¡Un error!') 
else:
    print('40. Todo bien por aquí.')
finally:
    print('    Se acabó el try.')
# Out:
# 35. ¡Un error!
# 36. ¡Un error! can only concatenate str (not "int") to str
# 37. <class 'TypeError'>
# 38. 18
# 39. Todo bien por aquí.
# 40. Todo bien por aquí.
#     Se acabó el try.

# %% [markdown]
# ---
#
# ## Ejercicios `continue`, `else`
#
# - Saltar iteraciones y terminar un `while`
#
#     41. Inicia `ahorros` a `5`. Mientras `ahorros` sea menos que `50` lo quiero subir con `10` y imprimir el valor. Si el valor es `25` no lo imprimes.
#     42. Amplia 41. para que te salga `'Tengo más que 50 en ahorros, dejo de aumentarlo.'`
#
# ---

# %%
# 41.
print('--- 41. ---')
ahorros = 5
while ahorros < 50:
    ahorros += 10
    if ahorros == 25:
        continue
    print(ahorros)

# 42.
print('--- 42. ---')
ahorros = 5
while ahorros < 50:
    ahorros += 10
    if ahorros == 25:
        continue
    print(ahorros)
else:
    print('Tengo más que 50 en ahorros, dejo de aumentarlo.')
# Out:
# --- 41. ---
# 15
# 35
# 45
# 55
# --- 42. ---
# 15
# 35
# 45
# 55
# Tengo más que 50 en ahorros, dejo de aumentarlo.
